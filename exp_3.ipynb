# %% [markdown]
# ## ML Experiment 3

# %%
# Import dependencies
import pandas as pd
import numpy as np
import psycopg2
import config as creds
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.inspection import permutation_importance

# %%
# Import data from AWS databse

def connect():
    
    # Set up a connection to the postgres server.
    conn_string = "host="+ creds.PGHOST +" port="+ "5432" +" dbname="+ creds.PGDATABASE +" user=" + creds.PGUSER \
                  +" password="+ creds.PGPASSWORD
    
    conn = psycopg2.connect(conn_string)
    print("Connected!")

    # Create a cursor object
    cursor = conn.cursor()
    
    return conn, cursor

conn, cursor=connect()
# Out:
# Connected!

# %%
# Read in the data from the database
listings_df = pd.read_sql_query("select * from nyc_listings", conn)
listings_df.head()
# Out:
#       id                                name  host_id            host_name  \
# 0  77765                Superior @ Box House   417504  The Box House Hotel
# 1   2539  Clean & quiet apt home by the park     2787                 John
# 2  45910  Beautiful Queens Brownstone! - 5BR   204539                 Mark
# 3  45936  Couldn't Be Closer To Columbia Uni   867225                Rahul
# 4  80493   Cozy room in East Village with AC   434987             Jennifer
#
#      borough         neighborhood  latitude  longitude        room_type  \
# 0   Brooklyn           Greenpoint  40.73777  -73.95366       Hotel room
# 1   Brooklyn           Kensington  40.64529  -73.97238     Private room
# 2     Queens            Ridgewood  40.70309  -73.89963  Entire home/apt
# 3  Manhattan  Morningside Heights  40.80630  -73.95985     Private room
# 4  Manhattan         East Village  40.72322  -73.98615     Private room
#
#    price  minimum_nights  number_of_reviews  availability_365  \
# 0    308               2                 42               217
# 1    299              30                  9               356
# 2    425              30                 13               365
# 3     75              31                135               219
# 4     55               2                207               132
#
#    days_since_last_review
# 0                      51
# 1                    1419
# 2                    1030
# 3                      58
# 4                      25

# %%
# Create a new feature with the average latitude and longitude
listings_df[['latitude', 'longitude']].mean()
# Out:
# latitude     40.727938
# longitude   -73.944307
# dtype: float64

# %%
# Drop unnecessary columns
listings_df=listings_df.drop(columns=['id', 'name', 'host_name', 'neighborhood', 'borough'])
listings_df.head()
# Out:
#    host_id  latitude  longitude        room_type  price  minimum_nights  \
# 0   417504  40.73777  -73.95366       Hotel room    308               2
# 1     2787  40.64529  -73.97238     Private room    299              30
# 2   204539  40.70309  -73.89963  Entire home/apt    425              30
# 3   867225  40.80630  -73.95985     Private room     75              31
# 4   434987  40.72322  -73.98615     Private room     55               2
#
#    number_of_reviews  availability_365  days_since_last_review
# 0                 42               217                      51
# 1                  9               356                    1419
# 2                 13               365                    1030
# 3                135               219                      58
# 4                207               132                      25

# %%
num_reviews_host=listings_df.groupby('host_id')['number_of_reviews'].sum()
num_reviews_host.name='num_reviews_host'

# %%
num_listings=listings_df.groupby('host_id').size()
num_listings.name='num_listings'

# %%
listings_df=listings_df.join(num_listings, on='host_id', how='outer').join(num_reviews_host, on='host_id', how='outer')
listings_df.head()
# Out:
#     host_id  latitude  longitude     room_type  price  minimum_nights  \
# 0    417504  40.73777  -73.95366    Hotel room    308               2
# 10   417504  40.73756  -73.95350    Hotel room    529               2
# 11   417504  40.73777  -73.95366  Private room    372               2
# 13   417504  40.73777  -73.95366  Private room    372               2
# 22   417504  40.73777  -73.95366    Hotel room    308               2
#
#     number_of_reviews  availability_365  days_since_last_review  num_listings  \
# 0                  42               217                      51            30
# 10                 10               100                     298            30
# 11                  9               222                       2            30
# 13                  2               222                    4136            30
# 22                 22               221                      88            30
#
#     num_reviews_host
# 0               1366
# 10              1366
# 11              1366
# 13              1366
# 22              1366

# %%
listings_df=listings_df.drop(columns=['host_id'])
listings_df.head()
# Out:
#     latitude  longitude     room_type  price  minimum_nights  \
# 0   40.73777  -73.95366    Hotel room    308               2
# 10  40.73756  -73.95350    Hotel room    529               2
# 11  40.73777  -73.95366  Private room    372               2
# 13  40.73777  -73.95366  Private room    372               2
# 22  40.73777  -73.95366    Hotel room    308               2
#
#     number_of_reviews  availability_365  days_since_last_review  num_listings  \
# 0                  42               217                      51            30
# 10                 10               100                     298            30
# 11                  9               222                       2            30
# 13                  2               222                    4136            30
# 22                 22               221                      88            30
#
#     num_reviews_host
# 0               1366
# 10              1366
# 11              1366
# 13              1366
# 22              1366

# %%
cat_df=pd.get_dummies(listings_df, columns=['room_type'])
cat_df.head()
# Out:
#     latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0   40.73777  -73.95366    308               2                 42
# 10  40.73756  -73.95350    529               2                 10
# 11  40.73777  -73.95366    372               2                  9
# 13  40.73777  -73.95366    372               2                  2
# 22  40.73777  -73.95366    308               2                 22
#
#     availability_365  days_since_last_review  num_listings  num_reviews_host  \
# 0                217                      51            30              1366
# 10               100                     298            30              1366
# 11               222                       2            30              1366
# 13               222                    4136            30              1366
# 22               221                      88            30              1366
#
#     room_type_Entire home/apt  room_type_Hotel room  room_type_Private room  \
# 0                           0                     1                       0
# 10                          0                     1                       0
# 11                          0                     0                       1
# 13                          0                     0                       1
# 22                          0                     1                       0
#
#     room_type_Shared room
# 0                       0
# 10                      0
# 11                      0
# 13                      0
# 22                      0

# %%
avg_lat, avg_long=cat_df[['latitude', 'longitude']].mean().values

# %%
# Create new column of distance
cat_df['distance']=((cat_df['latitude']-avg_lat)**2+(cat_df['longitude']-avg_long)**2)**.5
cat_df
# Out:
#         latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0      40.737770 -73.953660    308               2                 42
# 10     40.737560 -73.953500    529               2                 10
# 11     40.737770 -73.953660    372               2                  9
# 13     40.737770 -73.953660    372               2                  2
# 22     40.737770 -73.953660    308               2                 22
# ...          ...        ...    ...             ...                ...
# 31499  40.655910 -73.998570    145               3                 14
# 31500  40.740227 -74.027504    410               3                  2
# 31502  40.647244 -73.720088    180               1                  5
# 31503  40.787320 -74.004470    240               5                 18
# 31504  40.718350 -74.044160     40               1                 15
#
#        availability_365  days_since_last_review  num_listings  \
# 0                   217                      51            30
# 10                  100                     298            30
# 11                  222                       2            30
# 13                  222                    4136            30
# 22                  221                      88            30
# ...                 ...                     ...           ...
# 31499                 0                      12             1
# 31500                 0                      40             1
# 31502                 0                      14             1
# 31503               152                      16             1
# 31504                 0                     317             1
#
#        num_reviews_host  room_type_Entire home/apt  room_type_Hotel room  \
# 0                  1366                          0                     1
# 10                 1366                          0                     1
# 11                 1366                          0                     0
# 13                 1366                          0                     0
# 22                 1366                          0                     1
# ...                 ...                        ...                   ...
# 31499                14                          1                     0
# 31500                 2                          1                     0
# 31502                 5                          1                     0
# 31503                18                          1                     0
# 31504                15                          0                     0
#
#        room_type_Private room  room_type_Shared room  distance
# 0                           0                      0  0.013570
# 10                          0                      0  0.013307
# 11                          1                      0  0.013570
# 13                          1                      0  0.013570
# 22                          0                      0  0.013570
# ...                       ...                    ...       ...
# 31499                       0                      0  0.090181
# 31500                       0                      0  0.084099
# 31502                       0                      0  0.238298
# 31503                       0                      0  0.084533
# 31504                       1                      0  0.100312
#
# [31505 rows x 14 columns]

# %%
# Drop unnecessary columns
cat_df=cat_df.drop(columns=['latitude', 'longitude'])
cat_df
# Out:
#        price  minimum_nights  number_of_reviews  availability_365  \
# 0        308               2                 42               217
# 10       529               2                 10               100
# 11       372               2                  9               222
# 13       372               2                  2               222
# 22       308               2                 22               221
# ...      ...             ...                ...               ...
# 31499    145               3                 14                 0
# 31500    410               3                  2                 0
# 31502    180               1                  5                 0
# 31503    240               5                 18               152
# 31504     40               1                 15                 0
#
#        days_since_last_review  num_listings  num_reviews_host  \
# 0                          51            30              1366
# 10                        298            30              1366
# 11                          2            30              1366
# 13                       4136            30              1366
# 22                         88            30              1366
# ...                       ...           ...               ...
# 31499                      12             1                14
# 31500                      40             1                 2
# 31502                      14             1                 5
# 31503                      16             1                18
# 31504                     317             1                15
#
#        room_type_Entire home/apt  room_type_Hotel room  \
# 0                              0                     1
# 10                             0                     1
# 11                             0                     0
# 13                             0                     0
# 22                             0                     1
# ...                          ...                   ...
# 31499                          1                     0
# 31500                          1                     0
# 31502                          1                     0
# 31503                          1                     0
# 31504                          0                     0
#
#        room_type_Private room  room_type_Shared room  distance
# 0                           0                      0  0.013570
# 10                          0                      0  0.013307
# 11                          1                      0  0.013570
# 13                          1                      0  0.013570
# 22                          0                      0  0.013570
# ...                       ...                    ...       ...
# 31499                       0                      0  0.090181
# 31500                       0                      0  0.084099
# 31502                       0                      0  0.238298
# 31503                       0                      0  0.084533
# 31504                       1                      0  0.100312
#
# [31505 rows x 12 columns]

# %%
# Format and assign variables
X=cat_df.drop(columns=['price'])
y=cat_df['price']

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test=train_test_split(X, y)

# %%
# Scale the data
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
# Create and train the model
rf_valid=RandomForestRegressor()
rf_valid.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
# Generate the scores
print(f'Train R2 Score: {rf_valid.score(X_train_scaled, y_train)}')
print(f'Test R2 Score: {rf_valid.score(X_test_scaled, y_test)}')
# Out:
# Train R2 Score: 0.8605534917728701
# Test R2 Score: 0.15982996888373813

# %%
# Sort the features and their importance
sorted(list(zip(rf_valid.feature_importances_, X.columns)), reverse=True)
# Out:
# [(0.268309974796581, 'distance'),
#  (0.25895404297126207, 'days_since_last_review'),
#  (0.11379869769881382, 'availability_365'),
#  (0.11224307892401347, 'num_reviews_host'),
#  (0.08084123332242471, 'number_of_reviews'),
#  (0.06992185851943888, 'minimum_nights'),
#  (0.03604344953649665, 'num_listings'),
#  (0.03520907865316375, 'room_type_Private room'),
#  (0.01442784153345944, 'room_type_Entire home/apt'),
#  (0.00935135463262473, 'room_type_Shared room'),
#  (0.000899389411721584, 'room_type_Hotel room')]

# %% [markdown]
# ### Run a Model Price Prediction

# %%
X_train.columns
# Out:
# Index(['minimum_nights', 'number_of_reviews', 'availability_365',
#        'days_since_last_review', 'num_listings', 'num_reviews_host',
#        'room_type_Entire home/apt', 'room_type_Hotel room',
#        'room_type_Private room', 'room_type_Shared room', 'distance'],
#       dtype='object')

# %%
user_input = {
'minimum_nights': 3, 
'number_of_reviews': 5, 
'availability_365': 30,
'days_since_last_review': 20, 
'num_listings': 1, 
'num_reviews_host': 10,
'room_type_Entire home/apt':1, 
'room_type_Hotel room': 0,
'room_type_Private room': 0,
'room_type_Shared room': 0,
'distance': .01
}

# %%
list(user_input.values())
# Out:
# [3, 5, 30, 20, 1, 10, 1, 0, 0, 0, 0.01]

# %%
scaled_user_input=scaler.transform([list(user_input.values())])
scaled_user_input
# Out:
# C:\Users\lkcac\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py:446: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([[-0.47073077, -0.47151773, -0.74858577, -0.67863355, -0.28653664,
#         -0.24357778,  0.84471284, -0.07054356, -0.81389295, -0.11473492,
#         -1.34187358]])

# %%
rf_valid.predict(scaled_user_input)
# Out:
# array([317.89])
