# %%
import pandas as pd

df=pd.read_csv("listings.csv",sep=",")
df
# Out:
#                        id                                               name  \
# 0                   77765                               Superior @ Box House
# 1                    2539                 Clean & quiet apt home by the park
# 2                   45910                 Beautiful Queens Brownstone! - 5BR
# 3                   45935                       Room in Beautiful Townhouse.
# 4                   45936                 Couldn't Be Closer To Columbia Uni
# ...                   ...                                                ...
# 39876            27577588           Luxury Studio ON Grove Street E0C - B1CA
# 39877  654151117629853651                        Lovely 3- bedroom apartment
# 39878  553754115911961053          Trendy 3-bedroom apartment near Manhattan
# 39879  698195550745703156  Luxurious private waterfront terrace, 2BR 2BA Apt
# 39880            48971505           Just Blocks to Grove PATH and JC Med Ctr
#
# ...

# %%
df.drop(columns=['minimum_nights', 'number_of_reviews','last_review','reviews_per_month','calculated_host_listings_count','availability_365','number_of_reviews_ltm','license'],axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y8/z25h4y997psc483tj59t6x_w0000gn/T/ipykernel_59820/78036852.py in <module>
# ----> 1 df.drop(columns=['minimum_nights', 'number_of_reviews','last_review','reviews_per_month','calculated_host_listings_count','availability_365','number_of_reviews_ltm','license'],axis=0, inplace=True)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
# ...

# %%
df.drop(columns=['latitude','longitude'], axis=0, inplace=True)

# %%
df
# Out:
#                        id                                               name  \
# 10452            17984049                       Apartamento Algarve Holidays
# 39347            54104214           Lovely brownstone apartment close to NYC
# 39395            16556296  Entire 2 BR Apt 10 min. to NYC, steps to Dwntn...
# 39598  552167456542108301             Newly renovated condo, minutes to NYC!
# 39739            35165304  *IDEAL LOCATION *CHIC HOME*7 min to NYC**GROVE ST
#
#          host_id host_name neighbourhood_group      neighbourhood  \
# 10452  120181746    Isabel           Manhattan  Flatiron District
# 39347    6487132  Vladimir           Manhattan       Ellis Island
# 39395   91482234    Lauren           Manhattan       Ellis Island
# 39598  156830486  Krithika           Manhattan       Ellis Island
# 39739   13354338      Olga           Manhattan       Ellis Island
#
#              room_type  price
# 10452  Entire home/apt    143
# 39347  Entire home/apt    199
# ...
