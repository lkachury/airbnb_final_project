# %%
# Import dependencies
import pandas as pd
import numpy as np
import psycopg2
import config as creds
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.inspection import permutation_importance

# %%
# Import data from AWS databse

def connect():
    
    # Set up a connection to the postgres server.
    conn_string = "host="+ creds.PGHOST +" port="+ "5432" +" dbname="+ creds.PGDATABASE +" user=" + creds.PGUSER \
                  +" password="+ creds.PGPASSWORD
    
    conn = psycopg2.connect(conn_string)
    print("Connected!")

    # Create a cursor object
    cursor = conn.cursor()
    
    return conn, cursor

conn, cursor=connect()
# Out:
# Connected!

# %%
# Read in the data from the database
listings_df = pd.read_sql_query("select * from nyc_listings", conn)
listings_df
# Out:
#                        id                                          name  \
# 0                   77765                          Superior @ Box House
# 1                    2539            Clean & quiet apt home by the park
# 2                   45910            Beautiful Queens Brownstone! - 5BR
# 3                   45936            Couldn't Be Closer To Columbia Uni
# 4                   80493             Cozy room in East Village with AC
# ...                   ...                                           ...
# 31500  628769808856889664  Two bedroom apartment in Hoboken New Jersey.
# 31501            27577588      Luxury Studio ON Grove Street E0C - B1CA
# 31502  654151117629853651                   Lovely 3- bedroom apartment
# 31503  553754115911961053     Trendy 3-bedroom apartment near Manhattan
# 31504            48971505      Just Blocks to Grove PATH and JC Med Ctr
#
#          host_id            host_name    borough         neighborhood  \
# 0         417504  The Box House Hotel   Brooklyn           Greenpoint
# 1           2787                 John   Brooklyn           Kensington
# 2         204539                 Mark     Queens            Ridgewood
# 3         867225                Rahul  Manhattan  Morningside Heights
# 4         434987             Jennifer  Manhattan         East Village
# ...          ...                  ...        ...                  ...
# 31500   14468718                Burak  Manhattan         West Village
# 31501   37412692                  Kim  Manhattan         Ellis Island
# 31502  117540494               Miriam     Queens             Rosedale
# 31503   15048320                India  Manhattan      Upper West Side
# 31504      46201                    J  Manhattan         Ellis Island
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      40.737770 -73.953660       Hotel room    308               2
# 1      40.645290 -73.972380     Private room    299              30
# 2      40.703090 -73.899630  Entire home/apt    425              30
# 3      40.806300 -73.959850     Private room     75              31
# 4      40.723220 -73.986150     Private room     55               2
# ...          ...        ...              ...    ...             ...
# 31500  40.740227 -74.027504  Entire home/apt    410               3
# 31501  40.718220 -74.037940  Entire home/apt    135             365
# 31502  40.647244 -73.720088  Entire home/apt    180               1
# 31503  40.787320 -74.004470  Entire home/apt    240               5
# 31504  40.718350 -74.044160     Private room     40               1
#
#        number_of_reviews  availability_365  days_since_last_review
# 0                     42               217                      51
# 1                      9               356                    1419
# 2                     13               365                    1030
# 3                    135               219                      58
# 4                    207               132                      25
# ...                  ...               ...                     ...
# 31500                  2                 0                      40
# 31501                  2               365                    1087
# 31502                  5                 0                      14
# 31503                 18               152                      16
# 31504                 15                 0                     317
#
# [31505 rows x 14 columns]

# %%
listings_df=listings_df.drop(columns=['id', 'name', 'host_name', 'latitude', 'longitude'])

# %%
listings_df['borough_neighborhood']=listings_df['borough']+' '+listings_df['neighborhood']
listings_df.head()
# Out:
#    host_id    borough         neighborhood        room_type  price  \
# 0   417504   Brooklyn           Greenpoint       Hotel room    308
# 1     2787   Brooklyn           Kensington     Private room    299
# 2   204539     Queens            Ridgewood  Entire home/apt    425
# 3   867225  Manhattan  Morningside Heights     Private room     75
# 4   434987  Manhattan         East Village     Private room     55
#
#    minimum_nights  number_of_reviews  availability_365  \
# 0               2                 42               217
# 1              30                  9               356
# 2              30                 13               365
# 3              31                135               219
# 4               2                207               132
#
#    days_since_last_review           borough_neighborhood
# 0                      51            Brooklyn Greenpoint
# 1                    1419            Brooklyn Kensington
# 2                    1030               Queens Ridgewood
# 3                      58  Manhattan Morningside Heights
# 4                      25         Manhattan East Village

# %%
num_listings=listings_df.groupby('host_id').size()
num_listings.name='num_listings'

# %%
num_neighborhood=listings_df.groupby('borough_neighborhood').size()
num_neighborhood.name='num_neighborhood'

# %%
listings_df=listings_df.join(num_listings, on='host_id', how='outer').join(num_neighborhood, on='borough_neighborhood', how='outer')
listings_df.head()
# Out:
#     host_id   borough neighborhood     room_type  price  minimum_nights  \
# 0    417504  Brooklyn   Greenpoint    Hotel room    308               2
# 10   417504  Brooklyn   Greenpoint    Hotel room    529               2
# 11   417504  Brooklyn   Greenpoint  Private room    372               2
# 13   417504  Brooklyn   Greenpoint  Private room    372               2
# 22   417504  Brooklyn   Greenpoint    Hotel room    308               2
#
#     number_of_reviews  availability_365  days_since_last_review  \
# 0                  42               217                      51
# 10                 10               100                     298
# 11                  9               222                       2
# 13                  2               222                    4136
# 22                 22               221                      88
#
#    borough_neighborhood  num_listings  num_neighborhood
# 0   Brooklyn Greenpoint            30               573
# 10  Brooklyn Greenpoint            30               573
# 11  Brooklyn Greenpoint            30               573
# 13  Brooklyn Greenpoint            30               573
# 22  Brooklyn Greenpoint            30               573

# %%
listings_df=listings_df.drop(columns=['host_id', 'borough', 'neighborhood'])
listings_df.head()
# Out:
#        room_type  price  minimum_nights  number_of_reviews  availability_365  \
# 0     Hotel room    308               2                 42               217
# 10    Hotel room    529               2                 10               100
# 11  Private room    372               2                  9               222
# 13  Private room    372               2                  2               222
# 22    Hotel room    308               2                 22               221
#
#     days_since_last_review borough_neighborhood  num_listings  \
# 0                       51  Brooklyn Greenpoint            30
# 10                     298  Brooklyn Greenpoint            30
# 11                       2  Brooklyn Greenpoint            30
# 13                    4136  Brooklyn Greenpoint            30
# 22                      88  Brooklyn Greenpoint            30
#
#     num_neighborhood
# 0                573
# 10               573
# 11               573
# 13               573
# 22               573

# %%
cat_df=pd.get_dummies(listings_df, columns=['room_type', 'borough_neighborhood'])
cat_df.head()
# Out:
#     price  minimum_nights  number_of_reviews  availability_365  \
# 0     308               2                 42               217
# 10    529               2                 10               100
# 11    372               2                  9               222
# 13    372               2                  2               222
# 22    308               2                 22               221
#
#     days_since_last_review  num_listings  num_neighborhood  \
# 0                       51            30               573
# 10                     298            30               573
# 11                       2            30               573
# 13                    4136            30               573
# 22                      88            30               573
#
#     room_type_Entire home/apt  room_type_Hotel room  room_type_Private room  \
# 0                           0                     1                       0
# 10                          0                     1                       0
# 11                          0                     0                       1
# 13                          0                     0                       1
# 22                          0                     1                       0
#
#     ...  borough_neighborhood_Staten Island South Beach  \
# 0   ...                                               0
# 10  ...                                               0
# 11  ...                                               0
# 13  ...                                               0
# 22  ...                                               0
#
#     borough_neighborhood_Staten Island St. George  \
# 0                                               0
# 10                                              0
# 11                                              0
# 13                                              0
# 22                                              0
#
#     borough_neighborhood_Staten Island Stapleton  \
# 0                                              0
# 10                                             0
# 11                                             0
# 13                                             0
# 22                                             0
#
#     borough_neighborhood_Staten Island Todt Hill  \
# 0                                              0
# 10                                             0
# 11                                             0
# 13                                             0
# 22                                             0
#
#     borough_neighborhood_Staten Island Tompkinsville  \
# 0                                                  0
# 10                                                 0
# 11                                                 0
# 13                                                 0
# 22                                                 0
#
#     borough_neighborhood_Staten Island Tottenville  \
# 0                                                0
# 10                                               0
# 11                                               0
# 13                                               0
# 22                                               0
#
#     borough_neighborhood_Staten Island West Brighton  \
# 0                                                  0
# 10                                                 0
# 11                                                 0
# 13                                                 0
# 22                                                 0
#
#     borough_neighborhood_Staten Island Westerleigh  \
# 0                                                0
# 10                                               0
# 11                                               0
# 13                                               0
# 22                                               0
#
#     borough_neighborhood_Staten Island Willowbrook  \
# 0                                                0
# 10                                               0
# 11                                               0
# 13                                               0
# 22                                               0
#
#     borough_neighborhood_Staten Island Woodrow
# 0                                            0
# 10                                           0
# 11                                           0
# 13                                           0
# 22                                           0
#
# [5 rows x 252 columns]

# %%
X=cat_df.drop(columns='price')
y=cat_df['price']

# %%
rf=RandomForestRegressor()

# %%
rf.fit(X, y)
# Out:
# /Users/kevinlee/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor()

# %%
rf.score(X, y)
# Out:
# 0.874696522364114

# %%
sorted(list(zip(rf.feature_importances_, X.columns)), reverse=True)
# Out:
# [(0.24948137828501626, 'days_since_last_review'),
#  (0.22272091360919782, 'availability_365'),
#  (0.11598679616518762, 'number_of_reviews'),
#  (0.08289146736035088, 'minimum_nights'),
#  (0.07238321336763583, 'num_listings'),
#  (0.03355004796926131, 'borough_neighborhood_Manhattan East Harlem'),
#  (0.025864932302527885, 'room_type_Private room'),
#  (0.02291730369159598, 'room_type_Entire home/apt'),
#  (0.02134009141377597, 'borough_neighborhood_Manhattan Midtown'),
#  (0.020532435514123395, 'num_neighborhood'),
#  (0.010936555361332772, 'room_type_Shared room'),
#  (0.010040869748795919, 'borough_neighborhood_Manhattan Lower East Side'),
#  (0.008004807389148128, 'borough_neighborhood_Manhattan West Village'),
#  (0.007218898558009118, 'borough_neighborhood_Bronx Longwood'),
#  (0.006835692717616953, 'borough_neighborhood_Manhattan Financial District'),
#  (0.006316165642422554, 'borough_neighborhood_Manhattan Upper West Side'),
#  (0.005970515190499674, 'borough_neighborhood_Manhattan Tribeca'),
#  (0.0053317720062293185, 'borough_neighborhood_Manhattan SoHo'),
#  (0.004957920045586132, 'borough_neighborhood_Manhattan Upper East Side'),
#  (0.004852453087450805, 'borough_neighborhood_Manhattan Theater District'),
#  (0.0037643219317715316, 'borough_neighborhood_Brooklyn Canarsie'),
#  (0.0037009857245137038, "borough_neighborhood_Manhattan Hell's Kitchen"),
#  (0.0034521952112829086, 'borough_neighborhood_Manhattan Flatiron District'),
#  (0.003095695528688296, 'borough_neighborhood_Manhattan Chelsea'),
#  (0.0029898423861416147, 'borough_neighborhood_Manhattan Greenwich Village'),
#  (0.0028137506260175085, 'borough_neighborhood_Manhattan East Village'),
#  (0.0026485562499287078, 'borough_neighborhood_Manhattan Murray Hill'),
#  (0.0024457025385868406, 'borough_neighborhood_Brooklyn Crown Heights'),
#  (0.002256354406235219, 'borough_neighborhood_Manhattan Nolita'),
#  (0.002046464295983082, 'borough_neighborhood_Brooklyn Williamsburg'),
#  (0.0015581215902118702, 'borough_neighborhood_Queens Long Island City'),
#  (0.001419545019050584, 'borough_neighborhood_Staten Island Tompkinsville'),
#  (0.0014183901733668329, 'borough_neighborhood_Brooklyn Park Slope'),
#  (0.0013186903857664756, 'borough_neighborhood_Manhattan Kips Bay'),
#  (0.0012851756905463377, 'borough_neighborhood_Manhattan Harlem'),
#  (0.001247190750948783, 'room_type_Hotel room'),
#  (0.0011890282293977193, 'borough_neighborhood_Brooklyn Bushwick'),
#  (0.001133069067800305, 'borough_neighborhood_Manhattan Central Park'),
#  (0.0010658596278010554, 'borough_neighborhood_Brooklyn Prospect Heights'),
#  (0.0009000011095325502, 'borough_neighborhood_Brooklyn Fort Greene'),
#  (0.0008748768365755377, 'borough_neighborhood_Bronx Schuylerville'),
#  (0.0008527557166876926, 'borough_neighborhood_Brooklyn Gowanus'),
#  (0.0008378591931702413, 'borough_neighborhood_Brooklyn Boerum Hill'),
#  (0.0007840129228685531, 'borough_neighborhood_Queens Forest Hills'),
#  (0.0006887018718732608, 'borough_neighborhood_Queens Queens Village'),
#  (0.0006775839323670268, 'borough_neighborhood_Manhattan Washington Heights'),
#  (0.0006745283428876117, 'borough_neighborhood_Brooklyn Flatbush'),
#  (0.0006696005724079802, 'borough_neighborhood_Brooklyn Greenpoint'),
#  (0.0006284054295804137, 'borough_neighborhood_Manhattan Gramercy'),
#  (0.0006068373859944603, 'borough_neighborhood_Brooklyn Clinton Hill'),
#  (0.0005819269085838416, 'borough_neighborhood_Manhattan Chinatown'),
#  (0.0005199344855349866, 'borough_neighborhood_Brooklyn Downtown Brooklyn'),
#  (0.00048474395411364615, 'borough_neighborhood_Brooklyn Bedford-Stuyvesant'),
#  (0.00045728966484163215, 'borough_neighborhood_Brooklyn Kensington'),
#  (0.0004519685813899108, 'borough_neighborhood_Brooklyn Brooklyn Heights'),
#  (0.00045063713407964364, 'borough_neighborhood_Queens Flushing'),
#  (0.0004368534233612762, 'borough_neighborhood_Queens Arverne'),
#  (0.00039116218155885814, 'borough_neighborhood_Queens Far Rockaway'),
#  (0.00035673976317076493, 'borough_neighborhood_Brooklyn Carroll Gardens'),
#  (0.000332438767845034, 'borough_neighborhood_Manhattan Roosevelt Island'),
#  (0.0003145353556411063, 'borough_neighborhood_Manhattan Civic Center'),
#  (0.00030775170102752253, 'borough_neighborhood_Queens East Elmhurst'),
#  (0.00029635030750663145, 'borough_neighborhood_Manhattan Little Italy'),
#  (0.00026105369726228515, 'borough_neighborhood_Brooklyn Sunset Park'),
#  (0.00026040140841302617, 'borough_neighborhood_Brooklyn Vinegar Hill'),
#  (0.0002399241954331003, 'borough_neighborhood_Brooklyn East Flatbush'),
#  (0.00023001418769900172, 'borough_neighborhood_Brooklyn Cobble Hill'),
#  (0.00022824764335869395, 'borough_neighborhood_Manhattan NoHo'),
#  (0.0002220145464151301,
#   'borough_neighborhood_Brooklyn Prospect-Lefferts Gardens'),
#  (0.0002186985298039802, 'borough_neighborhood_Queens Rockaway Park'),
#  (0.00019456668291796357, 'borough_neighborhood_Manhattan Battery Park City'),
#  (0.00019017376958436045, 'borough_neighborhood_Brooklyn Flatlands'),
#  (0.00018954007883665284, 'borough_neighborhood_Brooklyn Navy Yard'),
#  (0.0001756011204309249, 'borough_neighborhood_Queens Astoria'),
#  (0.00016937030657374625, 'borough_neighborhood_Brooklyn South Slope'),
#  (0.00016836902091939388, 'borough_neighborhood_Queens Jamaica'),
#  (0.00016344841067829797, 'borough_neighborhood_Queens Kew Gardens Hills'),
#  (0.00015672561586559905, 'borough_neighborhood_Brooklyn Brownsville'),
#  (0.00014902254134386393, 'borough_neighborhood_Brooklyn Windsor Terrace'),
#  (0.00014583927901211393, 'borough_neighborhood_Brooklyn Columbia St'),
#  (0.0001445814266046107, 'borough_neighborhood_Staten Island Port Richmond'),
#  (0.00012699808606069098, 'borough_neighborhood_Brooklyn DUMBO'),
#  (0.0001252160652174428, 'borough_neighborhood_Manhattan Inwood'),
#  (0.0001204211149953477, 'borough_neighborhood_Queens Maspeth'),
#  (0.00011792909148910559, 'borough_neighborhood_Queens Ridgewood'),
#  (0.00010760065578945033, 'borough_neighborhood_Brooklyn Cypress Hills'),
#  (0.00010569878021409815, 'borough_neighborhood_Queens Ditmars Steinway'),
#  (0.00010293196194477433, 'borough_neighborhood_Staten Island Tottenville'),
#  (0.00010021938583510765, 'borough_neighborhood_Brooklyn Red Hook'),
#  (9.782008390239884e-05, 'borough_neighborhood_Bronx Wakefield'),
#  (9.579876109362151e-05, 'borough_neighborhood_Manhattan Morningside Heights'),
#  (9.294534190185664e-05, 'borough_neighborhood_Queens Cambria Heights'),
#  (9.057863311077595e-05, 'borough_neighborhood_Queens Woodside'),
#  (8.871729302080079e-05, 'borough_neighborhood_Brooklyn East New York'),
#  (8.626226471775071e-05, 'borough_neighborhood_Manhattan Stuyvesant Town'),
#  (8.489841732945417e-05, 'borough_neighborhood_Queens Rockaway Beach'),
#  (8.313300810838387e-05, 'borough_neighborhood_Brooklyn Bay Ridge'),
#  (8.240952157494699e-05, 'borough_neighborhood_Queens Sunnyside'),
#  (6.428651917567294e-05, 'borough_neighborhood_Queens Bayside'),
#  (6.372012953700063e-05, 'borough_neighborhood_Queens Fresh Meadows'),
#  (6.127766557524431e-05, 'borough_neighborhood_Queens St. Albans'),
#  (5.8355243991201056e-05, 'borough_neighborhood_Brooklyn Gravesend'),
#  (5.781581625329132e-05, 'borough_neighborhood_Queens Jamaica Estates'),
#  (5.600651267703006e-05, 'borough_neighborhood_Queens Springfield Gardens'),
#  (5.533685231095899e-05, 'borough_neighborhood_Bronx Morris Park'),
#  (5.3271987144642956e-05, 'borough_neighborhood_Queens Jackson Heights'),
#  (5.074147550216843e-05, 'borough_neighborhood_Queens Rego Park'),
#  (5.006518881464379e-05, 'borough_neighborhood_Queens South Ozone Park'),
#  (4.772587393785035e-05, 'borough_neighborhood_Queens Rosedale'),
#  (4.6935064522241916e-05, 'borough_neighborhood_Queens Elmhurst'),
#  (4.656104494610537e-05, 'borough_neighborhood_Bronx Port Morris'),
#  (4.465031262915581e-05, 'borough_neighborhood_Bronx Claremont Village'),
#  (4.2024058060636414e-05, 'borough_neighborhood_Brooklyn Sheepshead Bay'),
#  (4.182843388683225e-05, 'borough_neighborhood_Queens Edgemere'),
#  (4.1174020641648346e-05, 'borough_neighborhood_Manhattan Two Bridges'),
#  (4.11099894975041e-05, 'borough_neighborhood_Staten Island Clifton'),
#  (3.8578121023174035e-05, 'borough_neighborhood_Queens Laurelton'),
#  (3.716566917548469e-05, 'borough_neighborhood_Queens Briarwood'),
#  (3.6029599191404796e-05, 'borough_neighborhood_Manhattan Ellis Island'),
#  (3.447040487738321e-05, 'borough_neighborhood_Brooklyn Marine Park'),
#  (3.32027754010777e-05, 'borough_neighborhood_Bronx Kingsbridge'),
#  (3.315948029546387e-05, 'borough_neighborhood_Bronx Spuyten Duyvil'),
#  (3.306963366915966e-05, 'borough_neighborhood_Brooklyn Midwood'),
#  (3.221070827682079e-05, 'borough_neighborhood_Queens Richmond Hill'),
#  (3.13854804376258e-05, 'borough_neighborhood_Brooklyn Bath Beach'),
#  (3.051540413719904e-05, 'borough_neighborhood_Bronx Van Cortlandt Park'),
#  (3.03703820141425e-05, 'borough_neighborhood_Brooklyn Green-Wood Cemetery'),
#  (3.032365563176088e-05, 'borough_neighborhood_Queens Glendale'),
#  (3.0245301403458794e-05, 'borough_neighborhood_Bronx Mount Hope'),
#  (2.8864326045397532e-05, 'borough_neighborhood_Staten Island Arrochar'),
#  (2.828756086794495e-05, 'borough_neighborhood_Bronx Mott Haven'),
#  (2.690987468145282e-05, 'borough_neighborhood_Staten Island Stapleton'),
#  (2.6246130401022495e-05, 'borough_neighborhood_Queens Corona'),
#  (2.3514999152949283e-05, 'borough_neighborhood_Brooklyn Bensonhurst'),
#  (2.3411650919944406e-05, 'borough_neighborhood_Queens Kew Gardens'),
#  (2.2629736586529966e-05, 'borough_neighborhood_Manhattan Marble Hill'),
#  (2.2430981166448233e-05, 'borough_neighborhood_Brooklyn Bergen Beach'),
#  (2.198325025558373e-05, 'borough_neighborhood_Brooklyn Prospect Park'),
#  (2.182676021907294e-05, 'borough_neighborhood_Queens Ozone Park'),
#  (2.1479684635390825e-05, 'borough_neighborhood_Queens Howard Beach'),
#  (2.1338267611632146e-05, 'borough_neighborhood_Bronx Williamsbridge'),
#  (2.1202154760029578e-05, 'borough_neighborhood_Brooklyn Borough Park'),
#  (2.0798591293976015e-05, 'borough_neighborhood_Queens Hollis Hills'),
#  (2.018500844002304e-05, 'borough_neighborhood_Queens Woodhaven'),
#  (1.9281846980706857e-05, 'borough_neighborhood_Queens Whitestone'),
#  (1.9008099880813603e-05, 'borough_neighborhood_Queens College Point'),
#  (1.777000675190329e-05, 'borough_neighborhood_Bronx Parkchester'),
#  (1.7646118443251467e-05, 'borough_neighborhood_Brooklyn Dyker Heights'),
#  (1.6109923822516865e-05, 'borough_neighborhood_Bronx University Heights'),
#  (1.5871636383836237e-05, 'borough_neighborhood_Queens Belle Harbor'),
#  (1.4849573918264295e-05, 'borough_neighborhood_Bronx Morris Heights'),
#  (1.4705559925591953e-05, 'borough_neighborhood_Bronx Concourse'),
#  (1.4429175400798592e-05, 'borough_neighborhood_Bronx City Island'),
#  (1.4349214682843862e-05, 'borough_neighborhood_Brooklyn Brighton Beach'),
#  (1.4057804485687295e-05, 'borough_neighborhood_Bronx Tremont'),
#  (1.3425958205019973e-05, 'borough_neighborhood_Bronx Fordham'),
#  (1.2657201962949532e-05, 'borough_neighborhood_Staten Island Concord'),
#  (1.2614165762402109e-05, 'borough_neighborhood_Queens Middle Village'),
#  (1.178507930759104e-05, 'borough_neighborhood_Queens Little Neck'),
#  (1.1752357499150077e-05, 'borough_neighborhood_Staten Island Randall Manor'),
#  (1.0768666919092296e-05, 'borough_neighborhood_Staten Island Howland Hook'),
#  (1.03207019526919e-05, 'borough_neighborhood_Queens Jamaica Hills'),
#  (1.0046792269615534e-05, 'borough_neighborhood_Staten Island Emerson Hill'),
#  (9.996703855931618e-06, 'borough_neighborhood_Bronx Pelham Bay'),
#  (9.930247529736022e-06, 'borough_neighborhood_Staten Island Grymes Hill'),
#  (9.121137105858743e-06, 'borough_neighborhood_Bronx North Riverdale'),
#  (8.83197939474226e-06, 'borough_neighborhood_Bronx Allerton'),
#  (8.184700833312353e-06, 'borough_neighborhood_Bronx Belmont'),
#  (8.06193287843841e-06, 'borough_neighborhood_Queens Breezy Point'),
#  (8.05202341528716e-06, 'borough_neighborhood_Bronx Edenwald'),
#  (7.951389587790653e-06, 'borough_neighborhood_Staten Island Todt Hill'),
#  (7.568059362718468e-06, 'borough_neighborhood_Staten Island Willowbrook'),
#  (6.5844443016115126e-06, 'borough_neighborhood_Bronx Olinville'),
#  (6.574964326654289e-06, 'borough_neighborhood_Staten Island New Springville'),
#  (5.756925503169621e-06, 'borough_neighborhood_Staten Island St. George'),
#  (5.752741907035841e-06, 'borough_neighborhood_Bronx Clason Point'),
#  (5.085498763661293e-06, 'borough_neighborhood_Brooklyn Fort Hamilton'),
#  (5.0495212084640415e-06, 'borough_neighborhood_Queens Neponsit'),
#  (5.043263311413184e-06, 'borough_neighborhood_Bronx Van Nest'),
#  (5.016039800443493e-06, 'borough_neighborhood_Bronx Concourse Village'),
#  (4.849882400151928e-06, 'borough_neighborhood_Bronx Unionport'),
#  (4.8031794771264425e-06, 'borough_neighborhood_Bronx Throgs Neck'),
#  (4.712245959622261e-06, 'borough_neighborhood_Brooklyn Mill Basin'),
#  (4.614781232984251e-06, 'borough_neighborhood_Bronx Eastchester'),
#  (4.5039973087033605e-06, 'borough_neighborhood_Staten Island Dongan Hills'),
#  (4.410606756865489e-06, 'borough_neighborhood_Brooklyn Coney Island'),
#  (4.3582121725125e-06, 'borough_neighborhood_Queens Broad Channel'),
#  (4.2545982179870565e-06, 'borough_neighborhood_Bronx Melrose'),
#  (4.23978480075509e-06, 'borough_neighborhood_Bronx Baychester'),
#  (4.1965788088514705e-06, 'borough_neighborhood_Bronx Pelham Gardens'),
#  (4.013168092652266e-06, 'borough_neighborhood_Brooklyn Gerritsen Beach'),
#  (3.851942648188257e-06,
#   'borough_neighborhood_Staten Island Castleton Corners'),
#  (3.8511774536451265e-06, 'borough_neighborhood_Bronx Morrisania'),
#  (3.3682179525207187e-06, 'borough_neighborhood_Queens Bay Terrace'),
#  (3.1238448279373484e-06, 'borough_neighborhood_Queens Forest Park'),
#  (3.0068459628501744e-06, 'borough_neighborhood_Bronx Highbridge'),
#  (2.8978667990971426e-06, 'borough_neighborhood_Bronx East Morrisania'),
#  (2.822116595484744e-06, 'borough_neighborhood_Staten Island Park Hill'),
#  (2.665302423872545e-06, 'borough_neighborhood_Bronx Bronx Park'),
#  (2.5174208128799075e-06, 'borough_neighborhood_Queens Bellerose'),
#  (2.467328807336268e-06, 'borough_neighborhood_Bronx Norwood'),
#  (2.4219990463904263e-06, 'borough_neighborhood_Bronx Mount Eden'),
#  (2.265806047579128e-06, 'borough_neighborhood_Staten Island New Dorp Beach'),
#  (2.2473821020431313e-06, 'borough_neighborhood_Bronx Bronxdale'),
#  (2.234214911262466e-06, 'borough_neighborhood_Staten Island Port Ivory'),
#  (2.1865510977607456e-06, 'borough_neighborhood_Bronx Woodlawn'),
#  (2.1404170206227786e-06, 'borough_neighborhood_Queens Bayswater'),
#  (1.9010349756922786e-06, 'borough_neighborhood_Staten Island West Brighton'),
#  (1.8887980554949976e-06,
#   'borough_neighborhood_Staten Island Freshkills Park'),
#  (1.8061537076104177e-06,
#   'borough_neighborhood_Queens Flushing Meadows Corona Park'),
#  (1.7549299560693927e-06, 'borough_neighborhood_Queens Hollis'),
#  (1.5824929010692253e-06, 'borough_neighborhood_Brooklyn Sea Gate'),
#  (1.5292867825282244e-06, 'borough_neighborhood_Staten Island Midland Beach'),
#  (1.492445466785683e-06, 'borough_neighborhood_Staten Island Mariners Harbor'),
#  (1.3797408226882155e-06, 'borough_neighborhood_Staten Island Great Kills'),
#  (1.2655819877890398e-06, 'borough_neighborhood_Staten Island Rosebank'),
#  (1.2573593649484605e-06, 'borough_neighborhood_Staten Island Huguenot'),
#  (1.2250446555622895e-06, 'borough_neighborhood_Brooklyn Manhattan Beach'),
#  (1.1525255628360107e-06,
#   'borough_neighborhood_Staten Island Chelsea, Staten Island'),
#  (1.0373352176709924e-06, 'borough_neighborhood_Queens Floral Park'),
#  (1.019093071280525e-06, 'borough_neighborhood_Staten Island Lighthouse Hill'),
#  (1.002368666380611e-06, 'borough_neighborhood_Bronx Hunts Point'),
#  (9.8536496402467e-07, 'borough_neighborhood_Bronx Ferry Point Park'),
#  (9.456458382838809e-07, 'borough_neighborhood_Staten Island Oakwood'),
#  (8.438331000819245e-07, 'borough_neighborhood_Bronx Soundview'),
#  (7.311751541823632e-07, 'borough_neighborhood_Staten Island New Brighton'),
#  (7.156847972842781e-07, 'borough_neighborhood_Queens Douglaston'),
#  (6.403566350071153e-07, 'borough_neighborhood_Staten Island Shore Acres'),
#  (6.375169410821489e-07, 'borough_neighborhood_Bronx Riverdale'),
#  (5.8224378105849e-07, 'borough_neighborhood_Staten Island Grant City'),
#  (5.627929743264567e-07, 'borough_neighborhood_Staten Island Arden Heights'),
#  (3.9684246682291384e-07, "borough_neighborhood_Staten Island Prince's Bay"),
#  (3.8826851378163054e-07, 'borough_neighborhood_Staten Island Bloomfield'),
#  (2.957608688658479e-07, 'borough_neighborhood_Bronx Crotona Park'),
#  (2.4980168311928335e-07, 'borough_neighborhood_Bronx Fieldston'),
#  (1.9952412318905516e-07, 'borough_neighborhood_Bronx Westchester Square'),
#  (1.5976739292650832e-07, 'borough_neighborhood_Bronx Pelham Bay Park'),
#  (1.3180839797829452e-07, 'borough_neighborhood_Bronx Castle Hill'),
#  (1.201761327770943e-07, 'borough_neighborhood_Staten Island Graniteville'),
#  (1.128477399500966e-07, 'borough_neighborhood_Bronx Country Club'),
#  (7.668551922862227e-08, 'borough_neighborhood_Staten Island Silver Lake'),
#  (7.367965043809348e-08, 'borough_neighborhood_Staten Island Eltingville'),
#  (5.7503767464286815e-08, "borough_neighborhood_Staten Island Bull's Head"),
#  (5.4739499063307555e-08, 'borough_neighborhood_Staten Island South Beach'),
#  (4.843135553410539e-08, 'borough_neighborhood_Queens Holliswood'),
#  (3.314511369850033e-08, 'borough_neighborhood_Staten Island Woodrow'),
#  (2.6294799026485563e-08, 'borough_neighborhood_Staten Island Richmondtown'),
#  (1.9138161075988114e-08, 'borough_neighborhood_Bronx West Farms'),
#  (1.6566601161840915e-08, 'borough_neighborhood_Staten Island Westerleigh'),
#  (4.740150402772174e-09, 'borough_neighborhood_Queens LaGuardia Airport'),
#  (1.4337672633319576e-09, 'borough_neighborhood_Bronx Co-op City')]

# %%
rf_valid=RandomForestRegressor()

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y)

# %%
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
rf_valid.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor()

# %%
print(f'Train R2 Score: {rf_valid.score(X_train_scaled, y_train)}')
print(f'Test R2 Score: {rf_valid.score(X_test_scaled, y_test)}')
# Out:
# Train R2 Score: 0.8750190809938987
# Test R2 Score: 0.16306812572348783

# %%
sorted(list(zip(rf.feature_importances_, X.columns)), reverse=True)
# Out:
# [(0.24948137828501626, 'days_since_last_review'),
#  (0.22272091360919782, 'availability_365'),
#  (0.11598679616518762, 'number_of_reviews'),
#  (0.08289146736035088, 'minimum_nights'),
#  (0.07238321336763583, 'num_listings'),
#  (0.03355004796926131, 'borough_neighborhood_Manhattan East Harlem'),
#  (0.025864932302527885, 'room_type_Private room'),
#  (0.02291730369159598, 'room_type_Entire home/apt'),
#  (0.02134009141377597, 'borough_neighborhood_Manhattan Midtown'),
#  (0.020532435514123395, 'num_neighborhood'),
#  (0.010936555361332772, 'room_type_Shared room'),
#  (0.010040869748795919, 'borough_neighborhood_Manhattan Lower East Side'),
#  (0.008004807389148128, 'borough_neighborhood_Manhattan West Village'),
#  (0.007218898558009118, 'borough_neighborhood_Bronx Longwood'),
#  (0.006835692717616953, 'borough_neighborhood_Manhattan Financial District'),
#  (0.006316165642422554, 'borough_neighborhood_Manhattan Upper West Side'),
#  (0.005970515190499674, 'borough_neighborhood_Manhattan Tribeca'),
#  (0.0053317720062293185, 'borough_neighborhood_Manhattan SoHo'),
#  (0.004957920045586132, 'borough_neighborhood_Manhattan Upper East Side'),
#  (0.004852453087450805, 'borough_neighborhood_Manhattan Theater District'),
#  (0.0037643219317715316, 'borough_neighborhood_Brooklyn Canarsie'),
#  (0.0037009857245137038, "borough_neighborhood_Manhattan Hell's Kitchen"),
#  (0.0034521952112829086, 'borough_neighborhood_Manhattan Flatiron District'),
#  (0.003095695528688296, 'borough_neighborhood_Manhattan Chelsea'),
#  (0.0029898423861416147, 'borough_neighborhood_Manhattan Greenwich Village'),
#  (0.0028137506260175085, 'borough_neighborhood_Manhattan East Village'),
#  (0.0026485562499287078, 'borough_neighborhood_Manhattan Murray Hill'),
#  (0.0024457025385868406, 'borough_neighborhood_Brooklyn Crown Heights'),
#  (0.002256354406235219, 'borough_neighborhood_Manhattan Nolita'),
#  (0.002046464295983082, 'borough_neighborhood_Brooklyn Williamsburg'),
#  (0.0015581215902118702, 'borough_neighborhood_Queens Long Island City'),
#  (0.001419545019050584, 'borough_neighborhood_Staten Island Tompkinsville'),
#  (0.0014183901733668329, 'borough_neighborhood_Brooklyn Park Slope'),
#  (0.0013186903857664756, 'borough_neighborhood_Manhattan Kips Bay'),
#  (0.0012851756905463377, 'borough_neighborhood_Manhattan Harlem'),
#  (0.001247190750948783, 'room_type_Hotel room'),
#  (0.0011890282293977193, 'borough_neighborhood_Brooklyn Bushwick'),
#  (0.001133069067800305, 'borough_neighborhood_Manhattan Central Park'),
#  (0.0010658596278010554, 'borough_neighborhood_Brooklyn Prospect Heights'),
#  (0.0009000011095325502, 'borough_neighborhood_Brooklyn Fort Greene'),
#  (0.0008748768365755377, 'borough_neighborhood_Bronx Schuylerville'),
#  (0.0008527557166876926, 'borough_neighborhood_Brooklyn Gowanus'),
#  (0.0008378591931702413, 'borough_neighborhood_Brooklyn Boerum Hill'),
#  (0.0007840129228685531, 'borough_neighborhood_Queens Forest Hills'),
#  (0.0006887018718732608, 'borough_neighborhood_Queens Queens Village'),
#  (0.0006775839323670268, 'borough_neighborhood_Manhattan Washington Heights'),
#  (0.0006745283428876117, 'borough_neighborhood_Brooklyn Flatbush'),
#  (0.0006696005724079802, 'borough_neighborhood_Brooklyn Greenpoint'),
#  (0.0006284054295804137, 'borough_neighborhood_Manhattan Gramercy'),
#  (0.0006068373859944603, 'borough_neighborhood_Brooklyn Clinton Hill'),
#  (0.0005819269085838416, 'borough_neighborhood_Manhattan Chinatown'),
#  (0.0005199344855349866, 'borough_neighborhood_Brooklyn Downtown Brooklyn'),
#  (0.00048474395411364615, 'borough_neighborhood_Brooklyn Bedford-Stuyvesant'),
#  (0.00045728966484163215, 'borough_neighborhood_Brooklyn Kensington'),
#  (0.0004519685813899108, 'borough_neighborhood_Brooklyn Brooklyn Heights'),
#  (0.00045063713407964364, 'borough_neighborhood_Queens Flushing'),
#  (0.0004368534233612762, 'borough_neighborhood_Queens Arverne'),
#  (0.00039116218155885814, 'borough_neighborhood_Queens Far Rockaway'),
#  (0.00035673976317076493, 'borough_neighborhood_Brooklyn Carroll Gardens'),
#  (0.000332438767845034, 'borough_neighborhood_Manhattan Roosevelt Island'),
#  (0.0003145353556411063, 'borough_neighborhood_Manhattan Civic Center'),
#  (0.00030775170102752253, 'borough_neighborhood_Queens East Elmhurst'),
#  (0.00029635030750663145, 'borough_neighborhood_Manhattan Little Italy'),
#  (0.00026105369726228515, 'borough_neighborhood_Brooklyn Sunset Park'),
#  (0.00026040140841302617, 'borough_neighborhood_Brooklyn Vinegar Hill'),
#  (0.0002399241954331003, 'borough_neighborhood_Brooklyn East Flatbush'),
#  (0.00023001418769900172, 'borough_neighborhood_Brooklyn Cobble Hill'),
#  (0.00022824764335869395, 'borough_neighborhood_Manhattan NoHo'),
#  (0.0002220145464151301,
#   'borough_neighborhood_Brooklyn Prospect-Lefferts Gardens'),
#  (0.0002186985298039802, 'borough_neighborhood_Queens Rockaway Park'),
#  (0.00019456668291796357, 'borough_neighborhood_Manhattan Battery Park City'),
#  (0.00019017376958436045, 'borough_neighborhood_Brooklyn Flatlands'),
#  (0.00018954007883665284, 'borough_neighborhood_Brooklyn Navy Yard'),
#  (0.0001756011204309249, 'borough_neighborhood_Queens Astoria'),
#  (0.00016937030657374625, 'borough_neighborhood_Brooklyn South Slope'),
#  (0.00016836902091939388, 'borough_neighborhood_Queens Jamaica'),
#  (0.00016344841067829797, 'borough_neighborhood_Queens Kew Gardens Hills'),
#  (0.00015672561586559905, 'borough_neighborhood_Brooklyn Brownsville'),
#  (0.00014902254134386393, 'borough_neighborhood_Brooklyn Windsor Terrace'),
#  (0.00014583927901211393, 'borough_neighborhood_Brooklyn Columbia St'),
#  (0.0001445814266046107, 'borough_neighborhood_Staten Island Port Richmond'),
#  (0.00012699808606069098, 'borough_neighborhood_Brooklyn DUMBO'),
#  (0.0001252160652174428, 'borough_neighborhood_Manhattan Inwood'),
#  (0.0001204211149953477, 'borough_neighborhood_Queens Maspeth'),
#  (0.00011792909148910559, 'borough_neighborhood_Queens Ridgewood'),
#  (0.00010760065578945033, 'borough_neighborhood_Brooklyn Cypress Hills'),
#  (0.00010569878021409815, 'borough_neighborhood_Queens Ditmars Steinway'),
#  (0.00010293196194477433, 'borough_neighborhood_Staten Island Tottenville'),
#  (0.00010021938583510765, 'borough_neighborhood_Brooklyn Red Hook'),
#  (9.782008390239884e-05, 'borough_neighborhood_Bronx Wakefield'),
#  (9.579876109362151e-05, 'borough_neighborhood_Manhattan Morningside Heights'),
#  (9.294534190185664e-05, 'borough_neighborhood_Queens Cambria Heights'),
#  (9.057863311077595e-05, 'borough_neighborhood_Queens Woodside'),
#  (8.871729302080079e-05, 'borough_neighborhood_Brooklyn East New York'),
#  (8.626226471775071e-05, 'borough_neighborhood_Manhattan Stuyvesant Town'),
#  (8.489841732945417e-05, 'borough_neighborhood_Queens Rockaway Beach'),
#  (8.313300810838387e-05, 'borough_neighborhood_Brooklyn Bay Ridge'),
#  (8.240952157494699e-05, 'borough_neighborhood_Queens Sunnyside'),
#  (6.428651917567294e-05, 'borough_neighborhood_Queens Bayside'),
#  (6.372012953700063e-05, 'borough_neighborhood_Queens Fresh Meadows'),
#  (6.127766557524431e-05, 'borough_neighborhood_Queens St. Albans'),
#  (5.8355243991201056e-05, 'borough_neighborhood_Brooklyn Gravesend'),
#  (5.781581625329132e-05, 'borough_neighborhood_Queens Jamaica Estates'),
#  (5.600651267703006e-05, 'borough_neighborhood_Queens Springfield Gardens'),
#  (5.533685231095899e-05, 'borough_neighborhood_Bronx Morris Park'),
#  (5.3271987144642956e-05, 'borough_neighborhood_Queens Jackson Heights'),
#  (5.074147550216843e-05, 'borough_neighborhood_Queens Rego Park'),
#  (5.006518881464379e-05, 'borough_neighborhood_Queens South Ozone Park'),
#  (4.772587393785035e-05, 'borough_neighborhood_Queens Rosedale'),
#  (4.6935064522241916e-05, 'borough_neighborhood_Queens Elmhurst'),
#  (4.656104494610537e-05, 'borough_neighborhood_Bronx Port Morris'),
#  (4.465031262915581e-05, 'borough_neighborhood_Bronx Claremont Village'),
#  (4.2024058060636414e-05, 'borough_neighborhood_Brooklyn Sheepshead Bay'),
#  (4.182843388683225e-05, 'borough_neighborhood_Queens Edgemere'),
#  (4.1174020641648346e-05, 'borough_neighborhood_Manhattan Two Bridges'),
#  (4.11099894975041e-05, 'borough_neighborhood_Staten Island Clifton'),
#  (3.8578121023174035e-05, 'borough_neighborhood_Queens Laurelton'),
#  (3.716566917548469e-05, 'borough_neighborhood_Queens Briarwood'),
#  (3.6029599191404796e-05, 'borough_neighborhood_Manhattan Ellis Island'),
#  (3.447040487738321e-05, 'borough_neighborhood_Brooklyn Marine Park'),
#  (3.32027754010777e-05, 'borough_neighborhood_Bronx Kingsbridge'),
#  (3.315948029546387e-05, 'borough_neighborhood_Bronx Spuyten Duyvil'),
#  (3.306963366915966e-05, 'borough_neighborhood_Brooklyn Midwood'),
#  (3.221070827682079e-05, 'borough_neighborhood_Queens Richmond Hill'),
#  (3.13854804376258e-05, 'borough_neighborhood_Brooklyn Bath Beach'),
#  (3.051540413719904e-05, 'borough_neighborhood_Bronx Van Cortlandt Park'),
#  (3.03703820141425e-05, 'borough_neighborhood_Brooklyn Green-Wood Cemetery'),
#  (3.032365563176088e-05, 'borough_neighborhood_Queens Glendale'),
#  (3.0245301403458794e-05, 'borough_neighborhood_Bronx Mount Hope'),
#  (2.8864326045397532e-05, 'borough_neighborhood_Staten Island Arrochar'),
#  (2.828756086794495e-05, 'borough_neighborhood_Bronx Mott Haven'),
#  (2.690987468145282e-05, 'borough_neighborhood_Staten Island Stapleton'),
#  (2.6246130401022495e-05, 'borough_neighborhood_Queens Corona'),
#  (2.3514999152949283e-05, 'borough_neighborhood_Brooklyn Bensonhurst'),
#  (2.3411650919944406e-05, 'borough_neighborhood_Queens Kew Gardens'),
#  (2.2629736586529966e-05, 'borough_neighborhood_Manhattan Marble Hill'),
#  (2.2430981166448233e-05, 'borough_neighborhood_Brooklyn Bergen Beach'),
#  (2.198325025558373e-05, 'borough_neighborhood_Brooklyn Prospect Park'),
#  (2.182676021907294e-05, 'borough_neighborhood_Queens Ozone Park'),
#  (2.1479684635390825e-05, 'borough_neighborhood_Queens Howard Beach'),
#  (2.1338267611632146e-05, 'borough_neighborhood_Bronx Williamsbridge'),
#  (2.1202154760029578e-05, 'borough_neighborhood_Brooklyn Borough Park'),
#  (2.0798591293976015e-05, 'borough_neighborhood_Queens Hollis Hills'),
#  (2.018500844002304e-05, 'borough_neighborhood_Queens Woodhaven'),
#  (1.9281846980706857e-05, 'borough_neighborhood_Queens Whitestone'),
#  (1.9008099880813603e-05, 'borough_neighborhood_Queens College Point'),
#  (1.777000675190329e-05, 'borough_neighborhood_Bronx Parkchester'),
#  (1.7646118443251467e-05, 'borough_neighborhood_Brooklyn Dyker Heights'),
#  (1.6109923822516865e-05, 'borough_neighborhood_Bronx University Heights'),
#  (1.5871636383836237e-05, 'borough_neighborhood_Queens Belle Harbor'),
#  (1.4849573918264295e-05, 'borough_neighborhood_Bronx Morris Heights'),
#  (1.4705559925591953e-05, 'borough_neighborhood_Bronx Concourse'),
#  (1.4429175400798592e-05, 'borough_neighborhood_Bronx City Island'),
#  (1.4349214682843862e-05, 'borough_neighborhood_Brooklyn Brighton Beach'),
#  (1.4057804485687295e-05, 'borough_neighborhood_Bronx Tremont'),
#  (1.3425958205019973e-05, 'borough_neighborhood_Bronx Fordham'),
#  (1.2657201962949532e-05, 'borough_neighborhood_Staten Island Concord'),
#  (1.2614165762402109e-05, 'borough_neighborhood_Queens Middle Village'),
#  (1.178507930759104e-05, 'borough_neighborhood_Queens Little Neck'),
#  (1.1752357499150077e-05, 'borough_neighborhood_Staten Island Randall Manor'),
#  (1.0768666919092296e-05, 'borough_neighborhood_Staten Island Howland Hook'),
#  (1.03207019526919e-05, 'borough_neighborhood_Queens Jamaica Hills'),
#  (1.0046792269615534e-05, 'borough_neighborhood_Staten Island Emerson Hill'),
#  (9.996703855931618e-06, 'borough_neighborhood_Bronx Pelham Bay'),
#  (9.930247529736022e-06, 'borough_neighborhood_Staten Island Grymes Hill'),
#  (9.121137105858743e-06, 'borough_neighborhood_Bronx North Riverdale'),
#  (8.83197939474226e-06, 'borough_neighborhood_Bronx Allerton'),
#  (8.184700833312353e-06, 'borough_neighborhood_Bronx Belmont'),
#  (8.06193287843841e-06, 'borough_neighborhood_Queens Breezy Point'),
#  (8.05202341528716e-06, 'borough_neighborhood_Bronx Edenwald'),
#  (7.951389587790653e-06, 'borough_neighborhood_Staten Island Todt Hill'),
#  (7.568059362718468e-06, 'borough_neighborhood_Staten Island Willowbrook'),
#  (6.5844443016115126e-06, 'borough_neighborhood_Bronx Olinville'),
#  (6.574964326654289e-06, 'borough_neighborhood_Staten Island New Springville'),
#  (5.756925503169621e-06, 'borough_neighborhood_Staten Island St. George'),
#  (5.752741907035841e-06, 'borough_neighborhood_Bronx Clason Point'),
#  (5.085498763661293e-06, 'borough_neighborhood_Brooklyn Fort Hamilton'),
#  (5.0495212084640415e-06, 'borough_neighborhood_Queens Neponsit'),
#  (5.043263311413184e-06, 'borough_neighborhood_Bronx Van Nest'),
#  (5.016039800443493e-06, 'borough_neighborhood_Bronx Concourse Village'),
#  (4.849882400151928e-06, 'borough_neighborhood_Bronx Unionport'),
#  (4.8031794771264425e-06, 'borough_neighborhood_Bronx Throgs Neck'),
#  (4.712245959622261e-06, 'borough_neighborhood_Brooklyn Mill Basin'),
#  (4.614781232984251e-06, 'borough_neighborhood_Bronx Eastchester'),
#  (4.5039973087033605e-06, 'borough_neighborhood_Staten Island Dongan Hills'),
#  (4.410606756865489e-06, 'borough_neighborhood_Brooklyn Coney Island'),
#  (4.3582121725125e-06, 'borough_neighborhood_Queens Broad Channel'),
#  (4.2545982179870565e-06, 'borough_neighborhood_Bronx Melrose'),
#  (4.23978480075509e-06, 'borough_neighborhood_Bronx Baychester'),
#  (4.1965788088514705e-06, 'borough_neighborhood_Bronx Pelham Gardens'),
#  (4.013168092652266e-06, 'borough_neighborhood_Brooklyn Gerritsen Beach'),
#  (3.851942648188257e-06,
#   'borough_neighborhood_Staten Island Castleton Corners'),
#  (3.8511774536451265e-06, 'borough_neighborhood_Bronx Morrisania'),
#  (3.3682179525207187e-06, 'borough_neighborhood_Queens Bay Terrace'),
#  (3.1238448279373484e-06, 'borough_neighborhood_Queens Forest Park'),
#  (3.0068459628501744e-06, 'borough_neighborhood_Bronx Highbridge'),
#  (2.8978667990971426e-06, 'borough_neighborhood_Bronx East Morrisania'),
#  (2.822116595484744e-06, 'borough_neighborhood_Staten Island Park Hill'),
#  (2.665302423872545e-06, 'borough_neighborhood_Bronx Bronx Park'),
#  (2.5174208128799075e-06, 'borough_neighborhood_Queens Bellerose'),
#  (2.467328807336268e-06, 'borough_neighborhood_Bronx Norwood'),
#  (2.4219990463904263e-06, 'borough_neighborhood_Bronx Mount Eden'),
#  (2.265806047579128e-06, 'borough_neighborhood_Staten Island New Dorp Beach'),
#  (2.2473821020431313e-06, 'borough_neighborhood_Bronx Bronxdale'),
#  (2.234214911262466e-06, 'borough_neighborhood_Staten Island Port Ivory'),
#  (2.1865510977607456e-06, 'borough_neighborhood_Bronx Woodlawn'),
#  (2.1404170206227786e-06, 'borough_neighborhood_Queens Bayswater'),
#  (1.9010349756922786e-06, 'borough_neighborhood_Staten Island West Brighton'),
#  (1.8887980554949976e-06,
#   'borough_neighborhood_Staten Island Freshkills Park'),
#  (1.8061537076104177e-06,
#   'borough_neighborhood_Queens Flushing Meadows Corona Park'),
#  (1.7549299560693927e-06, 'borough_neighborhood_Queens Hollis'),
#  (1.5824929010692253e-06, 'borough_neighborhood_Brooklyn Sea Gate'),
#  (1.5292867825282244e-06, 'borough_neighborhood_Staten Island Midland Beach'),
#  (1.492445466785683e-06, 'borough_neighborhood_Staten Island Mariners Harbor'),
#  (1.3797408226882155e-06, 'borough_neighborhood_Staten Island Great Kills'),
#  (1.2655819877890398e-06, 'borough_neighborhood_Staten Island Rosebank'),
#  (1.2573593649484605e-06, 'borough_neighborhood_Staten Island Huguenot'),
#  (1.2250446555622895e-06, 'borough_neighborhood_Brooklyn Manhattan Beach'),
#  (1.1525255628360107e-06,
#   'borough_neighborhood_Staten Island Chelsea, Staten Island'),
#  (1.0373352176709924e-06, 'borough_neighborhood_Queens Floral Park'),
#  (1.019093071280525e-06, 'borough_neighborhood_Staten Island Lighthouse Hill'),
#  (1.002368666380611e-06, 'borough_neighborhood_Bronx Hunts Point'),
#  (9.8536496402467e-07, 'borough_neighborhood_Bronx Ferry Point Park'),
#  (9.456458382838809e-07, 'borough_neighborhood_Staten Island Oakwood'),
#  (8.438331000819245e-07, 'borough_neighborhood_Bronx Soundview'),
#  (7.311751541823632e-07, 'borough_neighborhood_Staten Island New Brighton'),
#  (7.156847972842781e-07, 'borough_neighborhood_Queens Douglaston'),
#  (6.403566350071153e-07, 'borough_neighborhood_Staten Island Shore Acres'),
#  (6.375169410821489e-07, 'borough_neighborhood_Bronx Riverdale'),
#  (5.8224378105849e-07, 'borough_neighborhood_Staten Island Grant City'),
#  (5.627929743264567e-07, 'borough_neighborhood_Staten Island Arden Heights'),
#  (3.9684246682291384e-07, "borough_neighborhood_Staten Island Prince's Bay"),
#  (3.8826851378163054e-07, 'borough_neighborhood_Staten Island Bloomfield'),
#  (2.957608688658479e-07, 'borough_neighborhood_Bronx Crotona Park'),
#  (2.4980168311928335e-07, 'borough_neighborhood_Bronx Fieldston'),
#  (1.9952412318905516e-07, 'borough_neighborhood_Bronx Westchester Square'),
#  (1.5976739292650832e-07, 'borough_neighborhood_Bronx Pelham Bay Park'),
#  (1.3180839797829452e-07, 'borough_neighborhood_Bronx Castle Hill'),
#  (1.201761327770943e-07, 'borough_neighborhood_Staten Island Graniteville'),
#  (1.128477399500966e-07, 'borough_neighborhood_Bronx Country Club'),
#  (7.668551922862227e-08, 'borough_neighborhood_Staten Island Silver Lake'),
#  (7.367965043809348e-08, 'borough_neighborhood_Staten Island Eltingville'),
#  (5.7503767464286815e-08, "borough_neighborhood_Staten Island Bull's Head"),
#  (5.4739499063307555e-08, 'borough_neighborhood_Staten Island South Beach'),
#  (4.843135553410539e-08, 'borough_neighborhood_Queens Holliswood'),
#  (3.314511369850033e-08, 'borough_neighborhood_Staten Island Woodrow'),
#  (2.6294799026485563e-08, 'borough_neighborhood_Staten Island Richmondtown'),
#  (1.9138161075988114e-08, 'borough_neighborhood_Bronx West Farms'),
#  (1.6566601161840915e-08, 'borough_neighborhood_Staten Island Westerleigh'),
#  (4.740150402772174e-09, 'borough_neighborhood_Queens LaGuardia Airport'),
#  (1.4337672633319576e-09, 'borough_neighborhood_Bronx Co-op City')]
